# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 30.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
pip install pyngrok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("/content/drive/MyDrive/all_games.csv")
df.head()
df.shape
# Out:
# (18800, 6)

# %%
df.describe(include='O')
# Out:
#          name platform       release_date  \
# count   18800    18800              18800
# unique  12254       22               4533
# top      Cars       PC  November 14, 2006
# freq        9     4864                 48
#
#                                                   summary user_review
# count                                               18686       18800
# unique                                              14647          94
# top     Iron Man, an explosive third-person action sho...         tbd
# freq                                                    7        1365

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18800 entries, 0 to 18799
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          18800 non-null  object
#  1   platform      18800 non-null  object
#  2   release_date  18800 non-null  object
#  3   summary       18686 non-null  object
#  4   meta_score    18800 non-null  int64
#  5   user_review   18800 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 881.4+ KB
# name              0
# platform          0
# release_date      0
# summary         114
# meta_score        0
# user_review       0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# name            0
# platform        0
# release_date    0
# summary         0
# meta_score      0
# user_review     0
# dtype: int64

# %%
df.head(10)
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
# 5                    Super Mario Galaxy             Wii   November 12, 2007
# 6                  Super Mario Galaxy 2             Wii        May 23, 2010
# 7                 Red Dead Redemption 2        Xbox One    October 26, 2018
# 8                    Grand Theft Auto V        Xbox One   November 18, 2014
# 9                    Grand Theft Auto V   PlayStation 3  September 17, 2013
#
#                                              summary  meta_score user_review
# ...

# %%
df.drop_duplicates('name', keep='first', inplace=True)
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (12159, 6)

# %%
df.columns
# Out:
# Index(['name', 'platform', 'release_date', 'summary', 'meta_score',
#        'user_review'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Assuming your DataFrame is named df
# Extract features from the 'summary' column
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df['summary'].fillna(''))

# Similarity Calculation
# Calculate cosine similarity between game summaries
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Recommendation Function
def recommend_games(game_name, num_recommendations=5):
    idx = df[df['name'] == game_name].index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:num_recommendations+1]
    game_indices = [i[0] for i in sim_scores]
    return df['name'].iloc[game_indices]

# Example usage:
recommended_games = recommend_games("Sekiro: Shadows Die Twice")
print("Recommended games for 'Sekiro: Shadows Die Twice':")
print(recommended_games)
# Out:
# Recommended games for 'Sekiro: Shadows Die Twice':
# 7760                                     Deracine
# 613                                     Deathloop
# 4908    The Dark Pictures Anthology: Man of Medan
# 6491                                The Splatters
# 1980              Dark Souls III: The Ringed City
# Name: name, dtype: object

# %% [markdown]
# # STREAMLIT

# %%
# !pip install -q streamlit

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the dataset
df = pd.read_csv("/content/drive/MyDrive/all_games.csv")
df.dropna(inplace=True)
df.drop_duplicates('name', keep='first', inplace=True)
df.reset_index(drop=True, inplace=True)

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df['summary'].values.astype('U'))

# Compute cosine similarity matrix
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Function to recommend games
def recommend_games(game_name, num_recommendations=5):
    idx = df[df['name'] == game_name].index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:num_recommendations+1]
    game_indices = [i[0] for i in sim_scores]
    return df.iloc[game_indices]

# Streamlit App
def main():
    # Custom CSS for enhanced styling
    st.markdown("""
        <style>
        .main {
            background-color: #000000;
        }
        .title {
            color: #4a90e2;
            font-size: 2.5em;
            font-weight: bold;
            text-align: center;
            margin-top: 20px;
        }
        .quote {
            color: #a3a3a3;
            font-size: 1.2em;
            text-align: center;
            margin: 20px 0;
        }
        .button {
            background-color: #4a90e2;
            color: white;
            font-size: 1.1em;
        }
        .button:hover {
            background-color: #357abd;
        }
        </style>
    """, unsafe_allow_html=True)

    # Top quote
    st.markdown("<div class='quote'>🎮 In the heart of every game lies the essence of adventure, challenge, and triumph. 🎮</div>", unsafe_allow_html=True)

    st.markdown("<div class='title'>Discover Your Next Adventure</div>", unsafe_allow_html=True)

    # Sidebar for user input
    game_name = st.selectbox("Select a game 🕹️", df['name'])
    num_recommendations = st.slider("Number of recommendations 🎲", 1, 10, 5)

    # Display recommendations if game name is provided
    if st.button("Recommend 📜", key='recommend', help="Get game recommendations based on your choice"):
        recommended_games = recommend_games(game_name, num_recommendations)
        st.subheader(f"Recommended games for '{game_name}':")
        st.write(recommended_games)

    # Bottom quote
    st.markdown("<div class='quote'>✨ The essence of gaming is not just about winning, but about the experience of the journey, the camaraderie, and the memories created along the way. ✨</div>", unsafe_allow_html=True)

if __name__ == "__main__":
    main()
# Out:
# Overwriting app.py

# %%
# !npm install localtunnel
# Out:
# up to date, audited 23 packages in 497ms
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 2 moderate severity vulnerabilities
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.

# %%
# !streamlit run app.py &>/content/logs.txt &
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Enpoint IP for localtunnel is: 34.125.173.19

# %%
# !npx localtunnel --port 8501
# Out:
# your url is: https://shaggy-ants-unite.loca.lt

# %%
from pyngrok import ngrok

# Terminate all ngrok processes
ngrok.kill()
